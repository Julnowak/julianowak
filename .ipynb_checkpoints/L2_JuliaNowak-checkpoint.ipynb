# %% [markdown]
# # Połączenie z bazą danych przy pomocy sqlAlchemy

# %%
from sqlalchemy import create_engine

db_string = "postgresql://wbauer_adb:adb2020@pgsql-196447.vipserv.org:5432/wbauer_adb"

db = create_engine(db_string)
connection_sqlalchemy = db.connect()

# %% [markdown]
# # Zapytanie do bazy i wypisanie wyników

# %%
result_set = db.execute("SELECT * FROM city")  
for r in result_set:  
    print(r)
# Out:
# (1, 'A Corua (La Corua)', 87, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (2, 'Abha', 82, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (3, 'Abu Dhabi', 101, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (4, 'Acua', 60, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (5, 'Adana', 97, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (6, 'Addis Abeba', 31, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (7, 'Aden', 107, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (8, 'Adoni', 44, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (9, 'Ahmadnagar', 44, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (10, 'Akishima', 50, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (11, 'Akron', 103, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (12, 'al-Ayn', 101, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (13, 'al-Hawiya', 82, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (14, 'al-Manama', 11, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (15, 'al-Qadarif', 89, datetime.datetime(2006, 2, 15, 9, 45, 25))
# ...

# %% [markdown]
# # Połączenie z bazą danych przy pomocy psycopg2 i pandas

# %%
import psycopg2 as pg
import pandas as pd

connection = pg.connect(host='pgsql-196447.vipserv.org', port=5432, dbname='wbauer_adb', user='wbauer_adb', password='adb2020')

# %% [markdown]
# # Zapytanie do bazy i wypisanie wyników

# %%
df = pd.read_sql('select * from city',con=connection)
df
# Out:
# C:\Users\Julia\anaconda3\envs\julianowak\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#      city_id                city  country_id         last_update
# 0          1  A Corua (La Corua)          87 2006-02-15 09:45:25
# 1          2                Abha          82 2006-02-15 09:45:25
# 2          3           Abu Dhabi         101 2006-02-15 09:45:25
# 3          4                Acua          60 2006-02-15 09:45:25
# 4          5               Adana          97 2006-02-15 09:45:25
# ..       ...                 ...         ...                 ...
# 595      596               Zaria          69 2006-02-15 09:45:25
# 596      597        Zeleznogorsk          80 2006-02-15 09:45:25
# 597      598         Zhezqazghan          51 2006-02-15 09:45:25
# ...

# %% [markdown]
# # Połączenie za pomocą sqlAlchemy i pandas

# %%
df = pd.read_sql('select * from city', con=connection_sqlalchemy)
df
# Out:
#      city_id                city  country_id         last_update
# 0          1  A Corua (La Corua)          87 2006-02-15 09:45:25
# 1          2                Abha          82 2006-02-15 09:45:25
# 2          3           Abu Dhabi         101 2006-02-15 09:45:25
# 3          4                Acua          60 2006-02-15 09:45:25
# 4          5               Adana          97 2006-02-15 09:45:25
# ..       ...                 ...         ...                 ...
# 595      596               Zaria          69 2006-02-15 09:45:25
# 596      597        Zeleznogorsk          80 2006-02-15 09:45:25
# 597      598         Zhezqazghan          51 2006-02-15 09:45:25
# 598      599            Zhoushan          23 2006-02-15 09:45:25
# 599      600          Ziguinchor          83 2006-02-15 09:45:25
#
# [600 rows x 4 columns]

# %% [markdown]
# # Zadanie 1
# ## Ile kategorii filmów mamy w wypożyczalni?

# %%
df = pd.read_sql('select count(name) from category', con=connection_sqlalchemy)
df
# Out:
#    count
# 0     16

# %% [markdown]
# Odp: Mamy 16 kategorii filmów.

# %% [markdown]
# # Zadanie 2
# ## Wyświetl listę kategorii w kolejności alfabetycznej.

# %%
df = pd.read_sql('select name from category order by name', con=connection_sqlalchemy)
df
# Out:
#            name
# 0        Action
# 1     Animation
# 2      Children
# 3      Classics
# 4        Comedy
# 5   Documentary
# 6         Drama
# 7        Family
# 8       Foreign
# 9         Games
# 10       Horror
# 11        Music
# 12          New
# 13       Sci-Fi
# 14       Sports
# 15       Travel

# %% [markdown]
# # Zadanie 3
# ## Znajdź najstarszy i najmłodszy film do wypożyczenia.

# %%
df = pd.read_sql('select * from film order by release_year', con=connection_sqlalchemy)
df
# Out:
#      film_id              title  \
# 0        133    Chamber Italian
# 1        384   Grosse Wonderful
# 2          8    Airport Pollock
# 3         98  Bright Encounters
# 4          1   Academy Dinosaur
# ..       ...                ...
# 995      996     Young Language
# 996      997         Youth Kick
# 997      998       Zhivago Core
# 998      999  Zoolander Fiction
# 999     1000          Zorro Ark
#
#                                            description  release_year  \
# 0    A Fateful Reflection of a Moose And a Husband ...          2006
# 1    A Epic Drama of a Cat And a Explorer who must ...          2006
# 2    A Epic Tale of a Moose And a Girl who must Con...          2006
# 3    A Fateful Yarn of a Lumberjack And a Feminist ...          2006
# 4    A Epic Drama of a Feminist And a Mad Scientist...          2006
# ..                                                 ...           ...
# 995  A Unbelieveable Yarn of a Boat And a Database ...          2006
# ...

# %% [markdown]
# Odp. Najstarszy film pochodzi z 2006 roku, a najmłodszy również z 2006 roku.

# %% [markdown]
# # Zadanie 4
# ## IIe wypożyczeń odbyło się między 2005-07-01 a 2005-08-01?

# %%
df = pd.read_sql("select * from rental where rental_date BETWEEN '2005-07-01' AND '2005-08-01';", con=connection_sqlalchemy)
df
# Out:
#       rental_id         rental_date  inventory_id  customer_id  \
# 0          3470 2005-07-05 22:49:24           883          565
# 1          3471 2005-07-05 22:51:44          1724          242
# 2          3472 2005-07-05 22:56:33           841           37
# 3          3473 2005-07-05 22:57:34          2735           60
# 4          3474 2005-07-05 22:59:53            97          594
# ...         ...                 ...           ...          ...
# 6704      10176 2005-07-31 23:40:35          1181           19
# 6705      10177 2005-07-31 23:42:33          2242          279
# 6706      10178 2005-07-31 23:43:04          1582          491
# 6707      10179 2005-07-31 23:49:54          2136          131
# 6708      10180 2005-07-31 23:57:43           757           50
#
#              return_date  staff_id         last_update
# 0    2005-07-07 19:36:24         1 2006-02-16 02:30:53
# 1    2005-07-13 01:38:44         2 2006-02-16 02:30:53
# ...

# %% [markdown]
# Odp: Pomiędzy 2005-07-01 a 2005-08-01 odbyło się 6709 wypożyczeń.

# %% [markdown]
# # Zadanie 5
# ## Ile wypożyczeń odbyło się między 2010-01-01 a 2011-02-01?

# %%
df = pd.read_sql("select * from rental where rental_date BETWEEN '2010-01-01' AND '2011-02-01';", con=connection_sqlalchemy)
df
# Out:
# Empty DataFrame
# Columns: [rental_id, rental_date, inventory_id, customer_id, return_date, staff_id, last_update]
# Index: []

# %% [markdown]
# Odp: Pomiędzy 2005-07-01 a 2005-08-01 nie odbyły się żadne wypożyczenia.

# %% [markdown]
# # Zadanie 6
# ## Znajdź największą płatność wypożyczenia.

# %%
df = pd.read_sql("select max(amount) from payment", con=connection_sqlalchemy)
df
# Out:
#      max
# 0  11.99

# %% [markdown]
# Odp: Największa płatność wyniosła 11.99.

# %% [markdown]
# # Zadanie 7
# ## Znajdź wszystkich klientów z Polski, Nigerii lub Bangladeszu.

# %%
df1 = pd.read_sql("select * from customer", con=connection_sqlalchemy)
df1
# Out:
#      customer_id  store_id first_name  last_name  \
# 0            524         1      Jared        Ely
# 1              1         1       Mary      Smith
# 2              2         1   Patricia    Johnson
# 3              3         1      Linda   Williams
# 4              4         2    Barbara      Jones
# ..           ...       ...        ...        ...
# 594          595         1   Terrence  Gunderson
# 595          596         1    Enrique   Forsythe
# 596          597         1    Freddie     Duggan
# 597          598         1       Wade   Delvalle
# 598          599         2     Austin    Cintron
#
#                                      email  address_id  activebool  \
# 0             jared.ely@sakilacustomer.org         530        True
# 1            mary.smith@sakilacustomer.org           5        True
# 2      patricia.johnson@sakilacustomer.org           6        True
# 3        linda.williams@sakilacustomer.org           7        True
# ...

# %%
df2 = pd.read_sql("select * from address", con=connection_sqlalchemy)
df2
# Out:
#      address_id                   address address2      district  city_id  \
# 0             1         47 MySakila Drive     None       Alberta      300
# 1             2        28 MySQL Boulevard     None           QLD      576
# 2             3         23 Workhaven Lane     None       Alberta      300
# 3             4      1411 Lillydale Drive     None           QLD      576
# 4             5            1913 Hanoi Way               Nagasaki      463
# ..          ...                       ...      ...           ...      ...
# 598         601       844 Bucuresti Place               Liaoning      242
# 599         602  1101 Bucuresti Boulevard            West Greece      401
# 600         603    1103 Quilmes Boulevard                  Piura      503
# 601         604       1331 Usak Boulevard                   Vaud      296
# 602         605      1325 Fukuyama Street           Heilongjiang      537
#
#     postal_code         phone         last_update
# ...

# %%
df3 = pd.read_sql("select * from country", con=connection_sqlalchemy)
df3


#df = pd.read_sql("select customer.first_name,customer.last_name from customer inner join customer.", con=connection_sqlalchemy)
#df
# Out:
#      country_id               country         last_update
# 0             1           Afghanistan 2006-02-15 09:44:00
# 1             2               Algeria 2006-02-15 09:44:00
# 2             3        American Samoa 2006-02-15 09:44:00
# 3             4                Angola 2006-02-15 09:44:00
# 4             5              Anguilla 2006-02-15 09:44:00
# ..          ...                   ...                 ...
# 104         105               Vietnam 2006-02-15 09:44:00
# 105         106  Virgin Islands, U.S. 2006-02-15 09:44:00
# 106         107                 Yemen 2006-02-15 09:44:00
# 107         108            Yugoslavia 2006-02-15 09:44:00
# 108         109                Zambia 2006-02-15 09:44:00
#
# [109 rows x 3 columns]

# %% [markdown]
# # Zadanie 8
# ## Gdzie mieszkają członkowie personelu?

# %%
df = pd.read_sql("select * from staff", con=connection_sqlalchemy)
df

df = pd.read_sql("select * from staff", con=connection_sqlalchemy)
df
# Out:
#    staff_id first_name last_name  address_id                         email  \
# 0         1       Mike   Hillyer           3  Mike.Hillyer@sakilastaff.com
# 1         2        Jon  Stephens           4  Jon.Stephens@sakilastaff.com
#
#    store_id  active username                                  password  \
# 0         1    True     Mike  8cb2237d0679ca88db6464eac60da96345513964
# 1         2    True      Jon  8cb2237d0679ca88db6464eac60da96345513964
#
#                  last_update  \
# 0 2006-05-16 16:13:11.793280
# 1 2006-05-16 16:13:11.793280
#
#                                              picture
# 0  [b'\x89', b'P', b'N', b'G', b'\r', b'\n', b'Z'...
# 1                                               None

# %% [markdown]
# # Zadanie 9
# ## Ilu pracowników mieszka w Argentynie lub Hiszpanii?

# %% [markdown]
# # Zadanie 10
# ## Jakie kategorie filmów zostały wypożyczone przez klientów?

# %% [markdown]
# # Zadanie 11
# ## Znajdź wszystkie kategorie filmów wypożyczonych w Ameryce.

# %% [markdown]
# # Zadanie 12
# ## Znajdź wszystkie tytuły filmów, w których grał: Olympia Pfeiffer lub Julia Zellweger lub Ellen Presley
